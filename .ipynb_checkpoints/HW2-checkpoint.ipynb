# %%
import pickle
import numpy as np

data = pickle.load(open('NoisyData.pickle','rb'))

mean = np.mean(data)
variance = np.var(data)
print(mean)
print(variance)

cov_matrix = np.cov(data, bias=True)
print(cov_matrix)
# Out:
# 3.0709022090810065
# 51.73307743243133
# 51.73307743243133

# %%
# Out:
# [[2.9741517548579472,
#   -8.057247082265375,
#   -8.108066193248078,
#   1.8668269921027603,
#   5.367987460695776,
#   3.9534422542581664,
#   -3.376558507429573,
#   0.7349871273458111,
#   2.1587235380175134,
#   5.294798272167407,
#   -0.46527567496330224,
#   -6.849331259041847,
#   4.5497521107342385,
#   -3.448947306819086,
#   2.6161632058935904,
#   1.7864882122012626,
#   3.072784143609104,
#   4.259019087959311,
#   0.5052223857661216,
#   6.423189750315721,
#   11.329910443724582,
#   7.920229341964866,
#   8.633072063232152,
#   -2.099315603183901,
#   0.7446359066193926,
#   6.655880281806217,
#   3.7119356214565005,
#   2.4230117040436587,
#   4.966085520268691,
#   -11.967980703398593,
#   1.7233185007529617,
#   1.1215973667457733,
#   7.96265302781365,
#   4.580472573829426,
#   1.3742244816726545,
#   15.978797643106962,
#   4.0313632621914754,
#   7.182166216667972,
#   2.558970920138672,
#   10.244301577861364,
#   -0.16773891647617667,
#   4.275193540578973,
# ...
